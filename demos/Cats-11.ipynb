# %%
import sys
sys.path.append('..')

# %%
from src import *

# %%
# Create an image PatternMatcher and see
# its original patterns

cs = ImageSampleGenerator('cats', sample_size=11)
cp = PatternMatcher(16, cs)

# %%
# Train and watch the patterns diverge

plot_image_grid(cp.patterns)

for j in range(8):
    for i in range(250):
        cp.train_sample()
    plot_image_grid(cp.patterns)
