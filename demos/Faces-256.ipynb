# %%
import sys
sys.path.append('..')

# %%
from src import *

# %%
# Create an image PatternMatcher

cs = ImageSampleGenerator('synth-faces', sample_size=256)
cp = PatternMatcher(20, cs)

# %%
# Train and watch the patterns diverge

# Notice how the skin tones all average out to a light color,
# This is a biased dataset.

plot_image_grid(cp.patterns)

for j in range(8):
    for i in range(250):
        cp.train_sample()
    plot_image_grid(cp.patterns)
