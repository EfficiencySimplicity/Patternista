# %%
import sys
sys.path.append('..')

# %%
from src import *

# %%
# Create an image PatternMatcher

cs = ImageSampleGenerator('numbers', sample_size=5)
cp = PatternMatcher(8, cs)

# %%
# Train and watch the patterns diverge

plot_image_grid(cp.patterns)

for j in range(8):
    for i in range(250):
        cp.train_sample()
    plot_image_grid(cp.patterns)
