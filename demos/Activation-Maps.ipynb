# %%
import sys
sys.path.append('..')

# %%
from src import *

import random

# %%
# Create an image PatternMatcher

cs = ImageSampleGenerator('cats', sample_size=11)
cp = PatternMatcher(16, cs)

# %%
# Train and watch the patterns diverge

plot_image_grid(cp.patterns)

for j in range(8):
    for i in range(250):
        cp.train_sample()
    plot_image_grid(cp.patterns)

# %%
image   = random.choice(cs.images)
act_map = cp.get_activation_map(image)
# Out:
# 0.25458526611328125
# 0.07383084297180176
